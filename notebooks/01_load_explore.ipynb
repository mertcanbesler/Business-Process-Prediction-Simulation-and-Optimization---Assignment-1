# %% [markdown]
# # General Overview for Understanding the Event-Log

# %%
# Importing the required libraries for process mining and data handling
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.objects.conversion.log import converter as log_converter
from pathlib import Path
import pandas as pd
import pm4py

# Defining the relative path to the raw event log

xes_path = Path("../data/raw/BPI_Challenge_2017.xes")

# Loading the event log using pm4py
# The imported log object contains all cases, events, and attributes
log = pm4py.read_xes(str(xes_path))

# Converting the event log to a pandas DataFrame
# This allows for easier inspection, filtering, and metric calculation
df = log_converter.apply(log, variant=log_converter.Variants.TO_DATA_FRAME)

# Displaying basic information about the dataset
print("✅ Event log successfully loaded!")
print(f"Rows: {len(df):,} | Columns: {len(df.columns)}")
print(df.dtypes)
# Showing the first few rows for an initial overview
df[df["Accepted"].notna()].head(1)
# Out:
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]
# ✅ Event log successfully loaded!
# Rows: 1,202,267 | Columns: 19
#     Action org:resource    concept:name EventOrigin          EventID  \
# 9  Created      User_52  O_Create Offer       Offer  Offer_148581083
#
#   lifecycle:transition                   time:timestamp  \
# 9             complete 2016-01-02 11:29:03.994000+00:00
#
#             case:LoanGoal case:ApplicationType      case:concept:name  \
# 9  Existing loan takeover           New credit  Application_652823628
#
#    case:RequestedAmount  FirstWithdrawalAmount  NumberOfTerms Accepted  \
# 9               20000.0                20000.0           44.0     True
#
#    MonthlyCost Selected  CreditScore  OfferedAmount OfferID
# 9       498.29     True        979.0        20000.0     NaN
