# %% [markdown]
# # Setup and Imports

# %%
# --- Core libraries ---
import pandas as pd
from pathlib import Path

# --- PM4Py modules (checked for 2.7.18) ---
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.objects.conversion.log import converter as log_converter

from pm4py.algo.discovery.inductive import algorithm as im
from pm4py.algo.discovery.heuristics import algorithm as hm

from pm4py.algo.evaluation.replay_fitness import algorithm as fitness_evaluator
from pm4py.algo.evaluation.precision import algorithm as precision_evaluator
from pm4py.algo.evaluation.generalization import algorithm as generalization_evaluator

# ✅ correct exporter path for pm4py 2.7.18
from pm4py.objects.petri_net.exporter import exporter as pnml_exporter

from pm4py.objects.conversion.process_tree import converter as pt_converter
from pm4py.objects.bpmn.exporter import exporter as bpmn_exporter

# --- Project structure ---
Path("models").mkdir(exist_ok=True)
Path("figs").mkdir(exist_ok=True)
Path("tables").mkdir(exist_ok=True)

# --- Column aliases used throughout ---
CASE = "case:concept:name"
ACT  = "concept:name"
TS   = "time:timestamp"
LIFE = "lifecycle:transition"

# %% [markdown]
# # Eventlog loading and pre-processing

# %%
# Load XES log and convert to DataFrame
xes_path = Path("../data/raw/BPI_Challenge_2017.xes")
log = xes_importer.apply(str(xes_path))
df = log_converter.apply(log, variant=log_converter.Variants.TO_DATA_FRAME)

print(f"✅ Event log loaded with {len(df):,} events and {df[CASE].nunique():,} cases.")
# Out:
# c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\util\dt_parsing\parser.py:82: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]
# ✅ Event log loaded with 1,202,267 events and 31,509 cases.

# %% [markdown]
# # Clean Log View for Discovery

# %%
# I work on a clean view for discovery:
# - only 'complete' lifecycle events (to avoid duplicates)
# - ensure chronological ordering
# - optional filter to keep only business activities (A_* and O_*)

df_view = df[[CASE, ACT, TS] + ([LIFE] if LIFE in df.columns else [])].copy()
df_view[TS] = pd.to_datetime(df_view[TS], errors="coerce")
if LIFE in df_view.columns:
    df_view = df_view[df_view[LIFE].astype(str).str.lower() == "complete"]

# Optional: focus on business steps only (uncomment if desired)
# df_view = df_view[df_view[ACT].str.startswith(("A_", "O_"))]

df_view = df_view.sort_values([CASE, TS], kind="mergesort").dropna(subset=[TS])

print(f"Events in view: {len(df_view):,} | Cases: {df_view[CASE].nunique():,}")
# Out:
# Events in view: 475,306 | Cases: 31,509

# %% [markdown]
# # Transformation to Event-Log

# %%
# Convert DataFrame to EventLog for discovery
elog = log_converter.apply(df_view, variant=log_converter.Variants.TO_EVENT_LOG)
print("EventLog created.")
# Out:
# EventLog created.

# %% [markdown]
# # Inductive Miner (IMf) Discovery

# %%
# Inductive Miner discovery (returns a Process Tree)
pt_im = im.apply(elog)

# Convert Process Tree to Petri Net
from pm4py.objects.conversion.process_tree import converter as tree_converter
net_im, im_im, fm_im = tree_converter.apply(pt_im, variant=tree_converter.Variants.TO_PETRI_NET)

print("Inductive Miner model discovered and converted to Petri net.")
# Out:
# Inductive Miner model discovered and converted to Petri net.

# %% [markdown]
# # Heuristics Miner Discovery

# %%
net_hm, im_hm, fm_hm = hm.apply(elog)
print("Heuristics Miner model discovered.")
# Out:
# Heuristics Miner model discovered.

# %% [markdown]
# # Evaluation (Replay Fitness)

# %%
# --- Fast version: Token-based Replay Fitness ---
fit_im = fitness_evaluator.apply(
    elog, net_im, im_im, fm_im,
    parameters={"variant": fitness_evaluator.Variants.TOKEN_BASED}
)["log_fitness"]

fit_hm = fitness_evaluator.apply(
    elog, net_hm, im_hm, fm_hm,
    parameters={"variant": fitness_evaluator.Variants.TOKEN_BASED}
)["log_fitness"]

print(f" Fitness IM: {fit_im:.3f} | Fitness HM: {fit_hm:.3f}")
# Out:
# aligning log, completed variants ::   0%|          | 0/5623 [00:00<?, ?it/s]
# aligning log, completed variants ::   0%|          | 0/5623 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 7
#       1 # --- Fast version: Token-based Replay Fitness ---
#       2 fit_im = fitness_evaluator.apply(
#       3     elog, net_im, im_im, fm_im,
#       4     parameters={"variant": fitness_evaluator.Variants.TOKEN_BASED}
#       5 )["log_fitness"]
# ----> 7 fit_hm = fitness_evaluator.apply(
#       8     elog, net_hm, im_hm, fm_hm,
#       9     parameters={"variant": fitness_evaluator.Variants.TOKEN_BASED}
#      10 )["log_fitness"]
#      12 print(f"⚡ Fitness IM: {fit_im:.3f} | Fitness HM: {fit_hm:.3f}")
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\algo\evaluation\replay_fitness\algorithm.py:123, in apply(log, petri_net, initial_marking, final_marking, parameters, variant, align_variant)
#     121 if align_variant is None:
#     122     align_variant = alignments.petri_net.algorithm.DEFAULT_VARIANT
# --> 123 return exec_utils.get_variant(variant).apply(
#     124     log,
#     125     petri_net,
#     126     initial_marking,
#     127     final_marking,
#     128     align_variant=align_variant,
#     129     parameters=parameters,
#     130 )
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\algo\evaluation\replay_fitness\variants\alignment_based.py:160, in apply(log, petri_net, initial_marking, final_marking, align_variant, parameters)
#     151         alignment_result = alignments.apply_multiprocessing(
#     152             log,
#     153             petri_net,
#    (...)
#     157             parameters=parameters,
#     158         )
#     159     else:
# --> 160         alignment_result = alignments.apply(
#     161             log,
#     162             petri_net,
#     163             initial_marking,
#     164             final_marking,
#     165             variant=align_variant,
#     166             parameters=parameters,
#     167         )
#     168 return evaluate(alignment_result)
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\algo\conformance\alignments\petri_net\algorithm.py:125, in apply(obj, petri_net, initial_marking, final_marking, parameters, variant)
#     116     return apply_trace(
#     117         obj,
#     118         petri_net,
#    (...)
#     122         variant=variant,
#     123     )
#     124 else:
# --> 125     return apply_log(
#     126         obj,
#     127         petri_net,
#     128         initial_marking,
#     129         final_marking,
#     130         parameters=parameters,
#     131         variant=variant,
#     132     )
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\algo\conformance\alignments\petri_net\algorithm.py:293, in apply_log(log, petri_net, initial_marking, final_marking, parameters, variant)
#     287 this_max_align_time = min(
#     288     max_align_time_case,
#     289     (max_align_time - (time.time() - start_time)) * 0.5,
#     290 )
#     291 parameters[Parameters.PARAM_MAX_ALIGN_TIME_TRACE] = this_max_align_time
#     292 all_alignments.append(
# --> 293     apply_trace(
#     294         trace,
#     295         petri_net,
#     296         initial_marking,
#     297         final_marking,
#     298         parameters=copy(parameters),
#     299         variant=variant,
#     300     )
#     301 )
#     302 if progress is not None:
#     303     progress.update()
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\algo\conformance\alignments\petri_net\algorithm.py:184, in apply_trace(trace, petri_net, initial_marking, final_marking, parameters, variant)
#     178 parameters = copy(parameters)
#     180 enable_best_worst_cost = exec_utils.get_param_value(
#     181     Parameters.ENABLE_BEST_WORST_COST, parameters, True
#     182 )
# --> 184 ali = exec_utils.get_variant(variant).apply(
#     185     trace, petri_net, initial_marking, final_marking, parameters=parameters
#     186 )
#     188 trace_cost_function = exec_utils.get_param_value(
#     189     Parameters.PARAM_TRACE_COST_FUNCTION, parameters, []
#     190 )
#     191 # Instead of using the length of the trace, use the sum of the trace cost
#     192 # function
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\algo\conformance\alignments\petri_net\variants\state_equation_a_star.py:212, in apply(trace, petri_net, initial_marking, final_marking, parameters)
#     202 else:
#     203     (
#     204         trace_net,
#     205         trace_im,
#    (...)
#     209         trace, trace_cost_function, activity_key=activity_key
#     210     )
# --> 212 alignment = apply_trace_net(
#     213     petri_net,
#     214     initial_marking,
#     215     final_marking,
#     216     trace_net,
#     217     trace_im,
#     218     trace_fm,
#     219     parameters,
#     220 )
#     222 return alignment
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\algo\conformance\alignments\petri_net\variants\state_equation_a_star.py:511, in apply_trace_net(petri_net, initial_marking, final_marking, trace_net, trace_im, trace_fm, parameters)
#     492     sync_prod, sync_initial_marking, sync_final_marking, cost_function = (
#     493         construct_cost_aware(
#     494             trace_net,
#    (...)
#     504         )
#     505     )
#     507 max_align_time_trace = exec_utils.get_param_value(
#     508     Parameters.PARAM_MAX_ALIGN_TIME_TRACE, parameters, sys.maxsize
#     509 )
# --> 511 alignment = apply_sync_prod(
#     512     sync_prod,
#     513     sync_initial_marking,
#     514     sync_final_marking,
#     515     cost_function,
#     516     utils.SKIP,
#     517     ret_tuple_as_trans_desc=ret_tuple_as_trans_desc,
#     518     max_align_time_trace=max_align_time_trace,
#     519 )
#     521 return_sync_cost = exec_utils.get_param_value(
#     522     Parameters.RETURN_SYNC_COST_FUNCTION, parameters, False
#     523 )
#     524 if return_sync_cost:
#     525     # needed for the decomposed alignments (switching them from
#     526     # state_equation_less_memory)
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\algo\conformance\alignments\petri_net\variants\state_equation_a_star.py:557, in apply_sync_prod(sync_prod, initial_marking, final_marking, cost_function, skip, ret_tuple_as_trans_desc, max_align_time_trace)
#     532 def apply_sync_prod(
#     533     sync_prod,
#     534     initial_marking,
#    (...)
#     539     max_align_time_trace=sys.maxsize,
#     540 ):
#     541     """
#     542     Performs the basic alignment search on top of the synchronous product net, given a cost function and skip-symbol
#     543
#    (...)
#     555     and **traversed_arcs**
#     556     """
# --> 557     return __search(
#     558         sync_prod,
#     559         initial_marking,
#     560         final_marking,
#     561         cost_function,
#     562         skip,
#     563         ret_tuple_as_trans_desc=ret_tuple_as_trans_desc,
#     564         max_align_time_trace=max_align_time_trace,
#     565     )
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\algo\conformance\alignments\petri_net\variants\state_equation_a_star.py:654, in __search(sync_net, ini, fin, cost_function, skip, ret_tuple_as_trans_desc, max_align_time_trace)
#     651     current_marking = curr.m
#     652     continue
# --> 654 h, x = utils.__compute_exact_heuristic_new_version(
#     655     sync_net,
#     656     a_matrix,
#     657     h_cvx,
#     658     g_matrix,
#     659     cost_vec,
#     660     incidence_matrix,
#     661     curr.m,
#     662     fin_vec,
#     663     lp_solver.DEFAULT_LP_SOLVER_VARIANT,
#     664     use_cvxopt=use_cvxopt,
#     665 )
#     666 lp_solved += 1
#     668 # 11/10/19: shall not a state for which we compute the exact heuristics be
#     669 # by nature a trusted solution?
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\objects\petri_net\utils\align_utils.py:312, in __compute_exact_heuristic_new_version(sync_net, a_matrix, h_cvx, g_matrix, cost_vec, incidence_matrix, marking, fin_vec, variant, use_cvxopt, strict)
#     308     b_term = matrix(b_term)
#     310 parameters_solving = {"solver": "glpk"}
# --> 312 sol = lp_solver.apply(
#     313     cost_vec,
#     314     g_matrix,
#     315     h_cvx,
#     316     a_matrix,
#     317     b_term,
#     318     parameters=parameters_solving,
#     319     variant=variant,
#     320 )
#     321 prim_obj = lp_solver.get_prim_obj_from_sol(sol, variant=variant)
#     322 points = lp_solver.get_points_from_sol(sol, variant=variant)
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\util\lp\solver.py:121, in apply(c, Aub, bub, Aeq, beq, parameters, variant)
#      93 def apply(
#      94     c, Aub, bub, Aeq, beq, parameters=None, variant=DEFAULT_LP_SOLVER_VARIANT
#      95 ):
#      96     """
#      97     Gets the overall solution of the problem
#      98
#    (...)
#     119         Solution of the LP problem by the given algorithm
#     120     """
# --> 121     return VERSIONS_APPLY[variant](
#     122         c, Aub, bub, Aeq, beq, parameters=parameters
#     123     )
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\util\lp\variants\cvxopt_solver_custom_align.py:74, in apply(c, Aub, bub, Aeq, beq, parameters)
#      50 def apply(c, Aub, bub, Aeq, beq, parameters=None):
#      51     """
#      52     Gets the overall solution of the problem
#      53
#    (...)
#      72         Solution of the LP problem by the given algorithm
#      73     """
# ---> 74     sol = custom_solve_lp(c, Aub, bub, Aeq, beq)
#      76     return sol
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\util\lp\variants\cvxopt_solver_custom_align.py:43, in custom_solve_lp(c, G, h, A, b)
#      40 status, x, z, y = glpk.lp(c, G, h, A, b, options=this_options)
#      42 if status == 'optimal':
# ---> 43     pcost = blas.dot(c, x)
#      44 else:
#      45     pcost = None
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluation (Precision)

# %%
prec_im = precision_evaluator.apply(elog, net_im, im_im, fm_im)
prec_hm = precision_evaluator.apply(elog, net_hm, im_hm, fm_hm)
print(f"Precision IM: {prec_im:.3f} | Precision HM: {prec_hm:.3f}")

# %% [markdown]
# # Evaluation (Generalization)

# %%
gen_im = generalization_evaluator.apply(elog, net_im, im_im, fm_im)
gen_hm = generalization_evaluator.apply(elog, net_hm, im_hm, fm_hm)
print(f"Generalization IM: {gen_im:.3f} | Generalization HM: {gen_hm:.3f}")

# %% [markdown]
# # Simplicity-Metrics

# %%
def simplicity_size(net):
    return len(net.places) + len(net.transitions)

def simplicity_density(net):
    arcs = sum(len(x.out_arcs) for x in list(net.places) + list(net.transitions))
    denom = max(1, len(net.places) * len(net.transitions))
    return arcs / denom

simp_size_im, simp_dens_im = simplicity_size(net_im), simplicity_density(net_im)
simp_size_hm, simp_dens_hm = simplicity_size(net_hm), simplicity_density(net_hm)

print(f"IM  -> size:{simp_size_im}  density:{simp_dens_im:.3f}")
print(f"HM  -> size:{simp_size_hm}  density:{simp_dens_hm:.3f}")

# %% [markdown]
# # Comparison Table

# %%
metrics_df = pd.DataFrame(
    [
        ["Inductive Miner",  fit_im, prec_im, gen_im, simp_size_im, simp_dens_im],
        ["Heuristics Miner", fit_hm, prec_hm, gen_hm, simp_size_hm, simp_dens_hm],
    ],
    columns=["Model", "Fitness", "Precision", "Generalization", "Simplicity(Size)", "Simplicity(Density)"]
)
metrics_df.to_csv("tables/model_quality_comparison.csv", index=False)
metrics_df

# %% [markdown]
# # Final Model Export (PNML + BPMN)

# %%
# Export final Inductive Miner model
pnml_exporter.apply(net_im, im_im, fm_im, "models/final_model.pnml")

# Export BPMN version via process tree
pt = im.apply_tree(elog)
bpmn_graph = pt_converter.apply(pt, variant=pt_converter.Variants.TO_BPMN)
bpmn_exporter.apply(bpmn_graph, "models/final_model.bpmn")

print("Final model exported: models/final_model.pnml and models/final_model.bpmn")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Export final Inductive Miner model
# ----> 2 pnml_exporter.apply(net_im, im_im, fm_im, "models/final_model.pnml")
#       4 # Export BPMN version via process tree
#       5 pt = im.apply_tree(elog)
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\objects\petri_net\exporter\exporter.py:62, in apply(net, initial_marking, output_filename, final_marking, variant, parameters)
#      35 def apply(
#      36     net,
#      37     initial_marking,
#    (...)
#      41     parameters=None,
#      42 ):
#      43     """
#      44     Export a Petri net along with an initial marking (and possibly a final marking) to an output file
#      45
#    (...)
#      60         Parameters of the exporter
#      61     """
# ---> 62     return exec_utils.get_variant(variant).export_net(
#      63         net,
#      64         initial_marking,
#      65         output_filename,
#      66         final_marking=final_marking,
#      67         parameters=parameters,
#      68     )
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\objects\petri_net\exporter\variants\pnml.py:382, in export_net(petrinet, marking, output_filename, final_marking, export_prom5, parameters)
#     377 encoding = exec_utils.get_param_value(
#     378     Parameters.ENCODING, parameters, constants.DEFAULT_ENCODING
#     379 )
#     381 # gets the XML tree
# --> 382 tree = export_petri_tree(
#     383     petrinet,
#     384     marking,
#     385     final_marking=final_marking,
#     386     export_prom5=export_prom5,
#     387 )
#     389 # write the tree to a file
#     390 F = open(output_filename, "wb")
#
# File c:\TUM Master\Business Process Prediction, Simulation and Optimization\Assignment 1\.venv\lib\site-packages\pm4py\objects\petri_net\exporter\variants\pnml.py:292, in export_petri_tree(petrinet, marking, final_marking, export_prom5, parameters)
#     290 for place in final_marking:
#     291     placem = etree.SubElement(marking, "place")
# --> 292     placem.set("idref", place.name)
#     293     placem_text = etree.SubElement(placem, "text")
#     294     placem_text.text = str(final_marking[place])
#
# AttributeError: 'str' object has no attribute 'name'

# %% [markdown]
# # Final Metrics Snapshot

# %%
final_row = metrics_df.loc[metrics_df["Model"]=="Inductive Miner"].iloc[0].to_dict()
pd.DataFrame([final_row]).to_csv("tables/final_model_metrics.csv", index=False)
print("Saved: tables/final_model_metrics.csv")
